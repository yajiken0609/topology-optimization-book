# %%
import numpy as np
x = np.array([1.0,  0.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
STEP_INIT = 1.0 # ステップ幅の初期値
TAU_ARM = 1e-4 # 傾きのパラメータ
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100000 # 外部反復の最大反復数
def f(x):
    return 2*x[0]**2+2*x[0]*x[1]+x[1]**2+x[0]-x[1] # 目的関数
def gradf(x):
    return np.array([4*x[0]+2*x[1]+1, 2*x[0]+2*x[1]-1]) # 勾配
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    t = STEP_INIT
    while (f(x-t*gradf(x)) > f(x)-TAU_ARM*np.dot(gradf(x),gradf(x))*t): 
        t *= STEP_DECAY # バックトラック法
    x -= t*gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.00, 0.00), f = 3.00000
# 1 iters, (-0.25, -0.25), f = 0.31250
# 2 iters, (0.00, 0.75), f = -0.18750
# 3 iters, (-0.62, 0.62), f = -0.85938
# 4 iters, (-0.50, 1.12), f = -0.98438
# 5 iters, (-0.81, 1.06), f = -1.15234
# 6 iters, (-0.75, 1.31), f = -1.18359
# 7 iters, (-0.91, 1.28), f = -1.22559
# 8 iters, (-0.88, 1.41), f = -1.23340
# 9 iters, (-0.95, 1.39), f = -1.24390
# 10 iters, (-0.94, 1.45), f = -1.24585
# 11 iters, (-0.98, 1.45), f = -1.24847
# 12 iters, (-0.97, 1.48), f = -1.24896
# 13 iters, (-0.99, 1.47), f = -1.24962
# 14 iters, (-0.98, 1.49), f = -1.24974
# 15 iters, (-0.99, 1.49), f = -1.24990
# 16 iters, (-0.99, 1.49), f = -1.24994
# 17 iters, (-1.00, 1.49), f = -1.24998
# 18 iters, (-1.00, 1.50), f = -1.24998
# 19 iters, (-1.00, 1.50), f = -1.24999
# 20 iters, (-1.00, 1.50), f = -1.25000
# 21 iters, (-1.00, 1.50), f = -1.25000
# 22 iters, (-1.00, 1.50), f = -1.25000
# 23 iters, (-1.00, 1.50), f = -1.25000
# 24 iters, (-1.00, 1.50), f = -1.25000
# ...

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-1.5, 1.5, 100)
y_p = np.linspace(-0.5, 2.5, 100)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.5,  2.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
STEP_INIT = 1.0 # ステップ幅の初期値
TAU_ARM = 1e-4 # 傾きのパラメータ
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100000 # 外部反復の最大反復数
def f(x):
    return (x[0]-1)**4+(x[0]-2*x[1])**2 # 目的関数
def gradf(x):
    return np.array([4*(x[0]-1)**3+2*(x[0]-2*x[1]), -4*(x[0]-2*x[1])]) # 勾配
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    t = STEP_INIT
    while (f(x-t*gradf(x)) > f(x)-TAU_ARM*np.dot(gradf(x),gradf(x))*t): 
        t *= STEP_DECAY # バックトラック法
    x -= t*gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(0.0, 3.0, 400)
y_p = np.linspace(0.0, 3.0, 400)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.0, -1.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
STEP_INIT = 1.0 # ステップ幅の初期値
TAU_ARM = 1e-4 # 傾きのパラメータ
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100000 # 外部反復の最大反復数
def f(x):
    return (x[0]**2+x[1]-11)**2+(x[0]+x[1]**2-7)**2 # 目的関数
def gradf(x):
    return np.array([4*x[0]*(x[0]**2+x[1]-11)+2*(x[0]+x[1]**2-7), 
                    2*(x[0]**2+x[1]-11)+4*x[1]*(x[0]+x[1]**2-7)]) # 勾配
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    t = STEP_INIT
    while (f(x-t*gradf(x)) > f(x)-TAU_ARM*np.dot(gradf(x),gradf(x))*t): 
        t *= STEP_DECAY # バックトラック法
    x -= t*gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.00, -1.00), f = 146.00000
# 1 iters, (4.38, -0.88), f = 56.24658
# 2 iters, (-3.34, -2.19), f = 34.88661
# 3 iters, (-3.84, -3.58), f = 3.92965
# 4 iters, (-3.86, -3.14), f = 1.49322
# 5 iters, (-3.65, -3.36), f = 1.48819
# 6 iters, (-3.78, -3.28), f = 0.00210
# 7 iters, (-3.78, -3.29), f = 0.00051
# 8 iters, (-3.78, -3.28), f = 0.00000
# 9 iters, (-3.78, -3.28), f = 0.00000
# 10 iters, (-3.78, -3.28), f = 0.00000
# 11 iters, (-3.78, -3.28), f = 0.00000
# 12 iters, (-3.78, -3.28), f = 0.00000
# 13 iters, (-3.78, -3.28), f = 0.00000
# 14 iters, (-3.78, -3.28), f = 0.00000
# 15 iters, (-3.78, -3.28), f = 0.00000
# 16 iters, (-3.78, -3.28), f = 0.00000
# 17 iters, (-3.78, -3.28), f = 0.00000
# 18 iters, (-3.78, -3.28), f = 0.00000

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-5.0, 5.0, 100)
y_p = np.linspace(-5.0, 5.0, 100)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([-1.0, 1.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
STEP_INIT = 1.0 # ステップ幅の初期値
TAU_ARM = 1e-4 # 傾きのパラメータ
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100000 # 外部反復の最大反復数
def f(x):
    return (x[0]**2+x[1]-11)**2+(x[0]+x[1]**2-7)**2 # 目的関数
def gradf(x):
    return np.array([4*x[0]*(x[0]**2+x[1]-11)+2*(x[0]+x[1]**2-7), 
                    2*(x[0]**2+x[1]-11)+4*x[1]*(x[0]+x[1]**2-7)]) # 勾配
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    t = STEP_INIT
    while (f(x-t*gradf(x)) > f(x)-TAU_ARM*np.dot(gradf(x),gradf(x))*t): 
        t *= STEP_DECAY # バックトラック法
    x -= t*gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (-1.00, 1.00), f = 130.00000
# 1 iters, (-2.38, 3.88), f = 34.02002
# 2 iters, (-2.77, 2.56), f = 11.09296
# 3 iters, (-2.80, 3.10), f = 0.04720
# 4 iters, (-2.80, 3.14), f = 0.00266
# 5 iters, (-2.81, 3.13), f = 0.00018
# 6 iters, (-2.81, 3.13), f = 0.00001
# 7 iters, (-2.81, 3.13), f = 0.00000
# 8 iters, (-2.81, 3.13), f = 0.00000
# 9 iters, (-2.81, 3.13), f = 0.00000
# 10 iters, (-2.81, 3.13), f = 0.00000
# 11 iters, (-2.81, 3.13), f = 0.00000
# 12 iters, (-2.81, 3.13), f = 0.00000
# 13 iters, (-2.81, 3.13), f = 0.00000
# 14 iters, (-2.81, 3.13), f = 0.00000
# 15 iters, (-2.81, 3.13), f = 0.00000
# 16 iters, (-2.81, 3.13), f = 0.00000

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-5.0, 5.0, 100)
y_p = np.linspace(-5.0, 5.0, 100)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.0,  0.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
ITR_MAX = 100 # 外部反復の最大反復数
def f(x):
    return 2*x[0]**2+2*x[0]*x[1]+x[1]**2+x[0]-x[1] # 目的関数
def gradf(x):
    return np.array([4*x[0]+2*x[1]+1, 2*x[0]+2*x[1]-1]) # 勾配
def Hessian():
    return np.array([[4, 2],[2, 2]]) # ヘッセ行列
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    inv_Hessian = np.linalg.inv(Hessian()) # ヘッセ行列の逆行列の計算
    x -= inv_Hessian@gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.00, 0.00), f = 3.00000
# 1 iters, (-1.00, 1.50), f = -1.25000

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-1.5, 1.5, 100)
y_p = np.linspace(-0.5, 2.5, 100)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.5,  2.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
ITR_MAX = 100 # 外部反復の最大反復数
def f(x):
    return (x[0]-1)**4+(x[0]-2*x[1])**2 # 目的関数
def gradf(x):
    return np.array([4*(x[0]-1)**3+2*(x[0]-2*x[1]), -4*(x[0]-2*x[1])]) # 勾配
def Hessian(x):
    return np.array([[12*(x[0]-1)**2+2, -4], [-4, 8]]) # ヘッセ行列
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    inv_Hessian = np.linalg.inv(Hessian(x)) # ヘッセ行列の逆行列の計算
    x -= inv_Hessian@gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.50, 2.00), f = 6.31250
# 1 iters, (1.33, 0.67), f = 0.01235
# 2 iters, (1.22, 0.61), f = 0.00244
# 3 iters, (1.15, 0.57), f = 0.00048
# 4 iters, (1.10, 0.55), f = 0.00010
# 5 iters, (1.07, 0.53), f = 0.00002
# 6 iters, (1.04, 0.52), f = 0.00000
# 7 iters, (1.03, 0.51), f = 0.00000
# 8 iters, (1.02, 0.51), f = 0.00000
# 9 iters, (1.01, 0.51), f = 0.00000
# 10 iters, (1.01, 0.50), f = 0.00000
# 11 iters, (1.01, 0.50), f = 0.00000
# 12 iters, (1.00, 0.50), f = 0.00000
# 13 iters, (1.00, 0.50), f = 0.00000

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(0.0, 3.0, 400)
y_p = np.linspace(0.0, 3.0, 400)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.0,  -1.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
ITR_MAX = 100 # 外部反復の最大反復数
def f(x):
    return (x[0]**2+x[1]-11)**2+(x[0]+x[1]**2-7)**2 # 目的関数
def gradf(x):
    return np.array([4*x[0]*(x[0]**2+x[1]-11)+2*(x[0]+x[1]**2-7), 
                     2*(x[0]**2+x[1]-11)+4*x[1]*(x[0]+x[1]**2-7)]) # 勾配
def Hessian(x):
    return np.array([[4*(x[0]**2+x[1]-11)+8*x[0]**2+2,4*x[0]+4*x[1]], 
                     [4*x[0]+4*x[1], 2+4*(x[0]+x[1]**2-7)+8*x[1]**2]]) # ヘッセ行列
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    inv_Hessian = np.linalg.inv(Hessian(x)) # ヘッセ行列の逆行列の計算
    x -= inv_Hessian@gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.00, -1.00), f = 146.00000
# 1 iters, (-0.59, -1.20), f = 178.31762
# 2 iters, (-0.28, -0.88), f = 181.59888
# 3 iters, (-0.27, -0.92), f = 181.61651
# 4 iters, (-0.27, -0.92), f = 181.61652
# 5 iters, (-0.27, -0.92), f = 181.61652

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-5.0, 5.0, 100)
y_p = np.linspace(-5.0, 5.0, 100)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([-1.0,  1.0]) # 設計変数の初期解
TOL_GRAD = 1e-7 # 収束判定のしきい値
ITR_MAX = 100 # 外部反復の最大反復数
def f(x):
    return (x[0]**2+x[1]-11)**2+(x[0]+x[1]**2-7)**2 # 目的関数
def gradf(x):
    return np.array([4*x[0]*(x[0]**2+x[1]-11)+2*(x[0]+x[1]**2-7), 
                     2*(x[0]**2+x[1]-11)+4*x[1]*(x[0]+x[1]**2-7)]) # 勾配
def Hessian(x):
    return np.array([[4*(x[0]**2+x[1]-11)+8*x[0]**2+2,4*x[0]+4*x[1]], 
                     [4*x[0]+4*x[1], 2+4*(x[0]+x[1]**2-7)+8*x[1]**2]]) # ヘッセ行列
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (np.linalg.norm(gradf(x)) < TOL_GRAD): break # 収束判定
    inv_Hessian = np.linalg.inv(Hessian(x)) # ヘッセ行列の逆行列の計算
    x -= inv_Hessian@gradf(x) # 設計変数の更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (-1.00, 1.00), f = 130.00000
# 1 iters, (-0.15, -1.56), f = 179.45983
# 2 iters, (0.00, -2.92), f = 196.22260
# 3 iters, (-0.07, -2.33), f = 180.29531
# 4 iters, (-0.11, -2.05), f = 178.44081
# 5 iters, (-0.13, -1.96), f = 178.33811
# 6 iters, (-0.13, -1.95), f = 178.33724
# 7 iters, (-0.13, -1.95), f = 178.33724
# 8 iters, (-0.13, -1.95), f = 178.33724

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-5.0, 5.0, 100)
y_p = np.linspace(-5.0, 5.0, 100)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
plt.contourf(X, Y, Z, levels=40, alpha=0.7)
plt.colorbar(label='$f$')
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], 'k.-', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], 'k.', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1], 'k*', markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.gca().set_aspect('equal')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.0,  0.0]) # 設計変数の初期解
TOL_X = 1e-7 # 収束判定のしきい値
STEP_INIT = 1.0 # ステップ幅の初期値
TAU_ARM = 1e-4 # 傾きのパラメータ
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100000 # 最大反復数
BOX_CONST = np.array([[-0.5, 1.0], [0.0, 1.5]]) # 側面制約
def f(x):
    return 2*x[0]**2+2*x[0]*x[1]+x[1]**2+x[0]-x[1] # 目的関数
def gradf(x):
    return np.array([4*x[0]+2*x[1]+1, 2*x[0]+2*x[1]-1]) # 勾配
trajectory = [x.copy()] # 設計変数の軌跡
norm_x = 1 # 収束判定のためのノルム(初期値を1に設定)
x_old = x # 1ステップ前の設計変数
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (norm_x < TOL_X): break # 収束判定
    t = STEP_INIT
    while (f(x-t*gradf(x)) > f(x)-TAU_ARM*np.dot(gradf(x),gradf(x))*t): 
        t *= STEP_DECAY # バックトラック法
    x -= t*gradf(x) # 設計変数の更新
    x = np.clip(x, BOX_CONST[:, 0], BOX_CONST[:, 1]) # クリップ関数
    norm_x = np.linalg.norm(x-x_old, 2) # 設計変数の残差ノルム
    x_old = x.copy()
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.00, 0.00), f = 3.00000
# 1 iters, (-0.25, 0.00), f = -0.12500
# 2 iters, (-0.25, 0.75), f = -0.68750
# 3 iters, (-0.50, 0.75), f = -0.93750
# 4 iters, (-0.50, 1.25), f = -0.93750
# 5 iters, (-0.50, 1.12), f = -0.98438
# 6 iters, (-0.50, 1.06), f = -0.99609
# 7 iters, (-0.50, 1.03), f = -0.99902
# 8 iters, (-0.50, 1.02), f = -0.99976
# 9 iters, (-0.50, 1.01), f = -0.99994
# 10 iters, (-0.50, 1.00), f = -0.99998
# 11 iters, (-0.50, 1.00), f = -1.00000
# 12 iters, (-0.50, 1.00), f = -1.00000
# 13 iters, (-0.50, 1.00), f = -1.00000
# 14 iters, (-0.50, 1.00), f = -1.00000
# 15 iters, (-0.50, 1.00), f = -1.00000
# 16 iters, (-0.50, 1.00), f = -1.00000
# 17 iters, (-0.50, 1.00), f = -1.00000
# 18 iters, (-0.50, 1.00), f = -1.00000
# 19 iters, (-0.50, 1.00), f = -1.00000
# 20 iters, (-0.50, 1.00), f = -1.00000
# 21 iters, (-0.50, 1.00), f = -1.00000
# 22 iters, (-0.50, 1.00), f = -1.00000
# 23 iters, (-0.50, 1.00), f = -1.00000
# 24 iters, (-0.50, 1.00), f = -1.00000
# ...

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-1.5, 1.5, 400)
y_p = np.linspace(-0.5, 2.5, 400)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
Bax = -X+BOX_CONST[0,0]
Bay = -Y+BOX_CONST[1,0]
Bbx = X-BOX_CONST[0,1]
Bby = Y-BOX_CONST[1,1]
feasible_region = (Bax < 0) & (Bay < 0) & (Bbx < 0) & (Bby < 0)
infeasible_region = (Bax > 0) | (Bay > 0) | (Bbx > 0) | (Bby > 0)
contour = plt.contourf(X, Y, Z, levels=40, cmap="viridis", alpha=0.7)
plt.colorbar(label='$f$')
plt.contourf(X, Y, infeasible_region, levels=[0.5, 1], colors='white', alpha=1.0)
plt.contour(X, Y, Z, levels=40, linestyles='-', linewidths=1, colors='gray', alpha=1)
const_ax = plt.contour(X, Y, Bax, levels=[0], linestyles='--', colors='black', linewidths=2)
const_ay = plt.contour(X, Y, Bay, levels=[0], linestyles='--', colors='black', linewidths=2)
const_bx = plt.contour(X, Y, Bbx, levels=[0], linestyles='--', colors='black', linewidths=2)
const_by = plt.contour(X, Y, Bby, levels=[0], linestyles='--', colors='black', linewidths=2)
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], color='k', marker='.', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], color='k', marker='.', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1],color='k', marker='*', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.gca().set_aspect('equal')
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.0,  0.0]) # 設計変数の初期解
TOL_X = 1e-7 # 収束判定のしきい値
STEP_INIT = 1.0 # ステップ幅の初期値
TAU_ARM = 1e-4 # 傾きのパラメータ
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100000 # 最大反復数
BOX_CONST = np.array([[-1.25, 0.25], [0.5, 2.0]]) # 側面制約
def f(x):
    return 2*x[0]**2+2*x[0]*x[1]+x[1]**2+x[0]-x[1] # 目的関数
def gradf(x):
    return np.array([4*x[0]+2*x[1]+1, 2*x[0]+2*x[1]-1]) # 勾配
trajectory = [x.copy()] # 設計変数の軌跡
norm_x = 1 # 収束判定のためのノルム(初期値を1に設定)
x_old = x # 1ステップ前の設計変数
for itr in range(ITR_MAX):
    print(f"{itr} iters, ({x[0]:.2f}, {x[1]:.2f}), f = {f(x):.5f}")
    if (norm_x < TOL_X): break # 収束判定
    t = STEP_INIT
    while (f(x-t*gradf(x)) > f(x)-TAU_ARM*np.dot(gradf(x),gradf(x))*t): 
        t *= STEP_DECAY # バックトラック法
    x -= t*gradf(x) # 設計変数の更新
    x = np.clip(x, BOX_CONST[:, 0], BOX_CONST[:, 1]) # クリップ関数
    norm_x = np.linalg.norm(x-x_old, 2) # 設計変数の残差ノルム
    x_old = x.copy()
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, (1.00, 0.00), f = 3.00000
# 1 iters, (-0.25, 0.50), f = -0.62500
# 2 iters, (-0.75, 0.75), f = -0.93750
# 3 iters, (-0.62, 1.00), f = -1.09375
# 4 iters, (-0.88, 1.12), f = -1.17188
# 5 iters, (-0.81, 1.25), f = -1.21094
# 6 iters, (-0.94, 1.31), f = -1.23047
# 7 iters, (-0.91, 1.38), f = -1.24023
# 8 iters, (-0.97, 1.41), f = -1.24512
# 9 iters, (-0.95, 1.44), f = -1.24756
# 10 iters, (-0.98, 1.45), f = -1.24878
# 11 iters, (-0.98, 1.47), f = -1.24939
# 12 iters, (-0.99, 1.48), f = -1.24969
# 13 iters, (-0.99, 1.48), f = -1.24985
# 14 iters, (-1.00, 1.49), f = -1.24992
# 15 iters, (-0.99, 1.49), f = -1.24996
# 16 iters, (-1.00, 1.49), f = -1.24998
# 17 iters, (-1.00, 1.50), f = -1.24999
# 18 iters, (-1.00, 1.50), f = -1.25000
# 19 iters, (-1.00, 1.50), f = -1.25000
# 20 iters, (-1.00, 1.50), f = -1.25000
# 21 iters, (-1.00, 1.50), f = -1.25000
# 22 iters, (-1.00, 1.50), f = -1.25000
# 23 iters, (-1.00, 1.50), f = -1.25000
# 24 iters, (-1.00, 1.50), f = -1.25000
# ...

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(-1.5, 1.5, 400)
y_p = np.linspace(-0.5, 2.5, 400)
X, Y = np.meshgrid(x_p, y_p)
Z = f(np.array([X, Y]))
Bax = -X+BOX_CONST[0,0]
Bay = -Y+BOX_CONST[1,0]
Bbx = X-BOX_CONST[0,1]
Bby = Y-BOX_CONST[1,1]
feasible_region = (Bax < 0) & (Bay < 0) & (Bbx < 0) & (Bby < 0)
infeasible_region = (Bax > 0) | (Bay > 0) | (Bbx > 0) | (Bby > 0)
contour = plt.contourf(X, Y, Z, levels=40, cmap="viridis", alpha=0.7)
plt.colorbar(label='$f$')
plt.contourf(X, Y, infeasible_region, levels=[0.5, 1], colors='white', alpha=1.0)
plt.contour(X, Y, Z, levels=40, linestyles='-', linewidths=1, colors='gray', alpha=1)
const_ax = plt.contour(X, Y, Bax, levels=[0], linestyles='--', colors='black', linewidths=2)
const_ay = plt.contour(X, Y, Bay, levels=[0], linestyles='--', colors='black', linewidths=2)
const_bx = plt.contour(X, Y, Bbx, levels=[0], linestyles='--', colors='black', linewidths=2)
const_by = plt.contour(X, Y, Bby, levels=[0], linestyles='--', colors='black', linewidths=2)
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], color='k', marker='.', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], color='k', marker='.', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1],color='k', marker='*', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.gca().set_aspect('equal')
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([1.0,  2.0]) # 設計変数の初期解
s = lam_s = np.ones(1) # スラック変数およびラグランジュ乗数の初期解
rho = 1.0 # バリアパラメータの初期値
RHO_TOL = 1e-7 # 収束判定のしきい値
TAU_TOL = 0.99 # ステップ幅の最大値を決めるパラメータ
KKT_COEF = 0.9 # 内部反復のしきい値を決めるパラメータ
RHO_DECAY = 0.1 # バリアパラメータの減少率
STEP_DECAY = 0.5 # ステップ幅の減少率
ITR_MAX = 100 # 外部反復の最大反復数
ind_z = np.cumsum([len(x), len(s), len(lam_s)])[:-1] # 解のインデックス
def compute_kkt(g, gradf, gradg, lam_s, s, rho):
    kkt = np.concatenate([
        gradf+lam_s*gradg, g+s, lam_s*s-rho])
    return kkt # KKT条件の等式をまとめたベクトル
def eval_func(x):
    f = (x[0]-1)**4+(x[0]-2*x[1])**2
    g = x[0]**2-x[1]
    return f, g # 評価関数
def grad(x):
    gradf = np.array([4*(x[0]-1)**3+2*(x[0]-2*x[1]), -4*(x[0]-2*x[1])])
    gradg = np.array([2*x[0], -1])
    return gradf, gradg # 評価関数の勾配
def Hessian(x):
    Hf = np.array([[12*(x[0]-1)**2+2, -4], [-4, 8]])
    Hg = np.array([[2, 0], [0, 0]])
    return Hf, Hg # 評価関数のヘッセ行列
trajectory = [x.copy()] # 設計変数の軌跡
for itr in range(ITR_MAX):
    f, g = eval_func(x)
    gradf, gradg = grad(x)
    tmp_kkt = compute_kkt(g, gradf, gradg, lam_s, s, rho)
    norm_l2_kkt = np.linalg.norm(tmp_kkt, 2) # ユークリッドノルム
    norm_inf_kkt = np.linalg.norm(tmp_kkt, np.inf) # 最大値ノルム
    print(f"{itr} iters, x = ({x[0]:.3f}, {x[1]:.3f}), rho = {rho:.1e}, norm_inf_kkt = {norm_inf_kkt:.1e}")
    if rho < RHO_TOL: break # 外部反復の収束判定
    while norm_inf_kkt > KKT_COEF*rho: # 内部反復
        _, g = eval_func(x)
        gradf, gradg = grad(x)
        Hf, Hg1 = Hessian(x)
        J = np.zeros((4, 4)) # ニュートン法のためのヤコビ行列
        J[np.ix_(np.array([0, 1]),np.array([0, 1]))] += Hf+lam_s*Hg1
        J[np.ix_(np.array([3, 3]),np.array([0, 1]))] += gradg
        J[np.ix_(np.array([0, 1]),np.array([3, 3]))] += gradg[:, None]
        J[3, 2] += 1
        J[2, 3] += s[0]
        J[2, 2] += lam_s[0]
        r_rho = np.zeros(4) # ニュートン法のための右辺ベクトル
        r_rho[[0, 1]] -= gradf+lam_s[0]*gradg
        r_rho[2] -= lam_s[0]*s[0]-rho
        r_rho[3] -= g+s[0]
        dz = np.linalg.solve(J, r_rho) # 連立方程式の求解
        dx, ds, dlam_s = np.split(dz, ind_z) 
        inv_t = np.maximum(-ds/(TAU_TOL*s), -dlam_s/(TAU_TOL*lam_s))
        t = 1/np.maximum(inv_t, 1) # 最大許容ステップ幅
        x_old, s_old, lam_s_old = x.copy(), s.copy(), lam_s.copy()
        tmp_norm_l2_kkt = 2*norm_l2_kkt            
        while tmp_norm_l2_kkt > norm_l2_kkt: # 残差ノルムによる直線探索
            x, s, lam_s = x_old+t*dx, s_old+t*ds, lam_s_old+t*dlam_s
            _, g = eval_func(x)
            gradf, gradg = grad(x)
            tmp_kkt = compute_kkt(g, gradf, gradg, lam_s, s, rho)
            tmp_norm_l2_kkt = np.linalg.norm(tmp_kkt, 2)                
            t = STEP_DECAY*t
        norm_l2_kkt = tmp_norm_l2_kkt
        norm_inf_kkt = np.linalg.norm(tmp_kkt, np.inf)
    rho = RHO_DECAY*rho # バリアパラメータの更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, x = (1.000, 2.000), rho = 1.0e+00, norm_inf_kkt = 1.1e+01
# 1 iters, x = (0.415, 0.436), rho = 1.0e-01, norm_inf_kkt = 5.0e-01
# 2 iters, x = (0.501, 0.368), rho = 1.0e-02, norm_inf_kkt = 1.0e-01
# 3 iters, x = (0.567, 0.346), rho = 1.0e-03, norm_inf_kkt = 1.2e-02
# 4 iters, x = (0.586, 0.346), rho = 1.0e-04, norm_inf_kkt = 9.2e-04
# 5 iters, x = (0.588, 0.346), rho = 1.0e-05, norm_inf_kkt = 1.1e-04
# 6 iters, x = (0.588, 0.346), rho = 1.0e-06, norm_inf_kkt = 9.2e-06
# 7 iters, x = (0.588, 0.346), rho = 1.0e-07, norm_inf_kkt = 9.0e-07
# 8 iters, x = (0.588, 0.346), rho = 1.0e-08, norm_inf_kkt = 9.0e-08

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(0, 3, 400)
y_p = np.linspace(0, 3, 400)
X, Y = np.meshgrid(x_p, y_p)
Z, G1 = eval_func(np.array([X, Y]))
feasible_region = (G1 < 0) 
infeasible_region = (G1 > 0) 
contour = plt.contourf(X, Y, Z, levels=40, cmap="viridis", alpha=0.7)
plt.colorbar(label='$f$')
plt.contourf(X, Y, infeasible_region, levels=[0.5, 1], colors='white', alpha=1.0)
constraint1 = plt.contour(X, Y, G1, levels=[0], linestyles='--', colors='black', linewidths=2)
plt.contour(X, Y, Z, levels=40, linestyles='-', linewidths=1, colors='gray', alpha=1)
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], color='k', marker='.', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], color='k', marker='.', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1],color='k', marker='*', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.gca().set_aspect('equal')
plt.legend(framealpha=1)

# %%
import numpy as np
x = np.array([2.0,  1.0]) # 設計変数の初期解
s = lam_s = np.ones(1) # スラック変数およびラグランジュ乗数の初期解
rho = 1.0 # バリアパラメータの初期値
RHO_TOL = 1e-7 # 収束判定のしきい値
TAU_TOL = 0.99 # ステップ幅の最大値を決めるパラメータ
KKT_COEF = 0.9 # 内部反復のしきい値を決めるパラメータ
RHO_DECAY = 0.1 # バリアパラメータの減少率
STEP_DECAY = 0.5 # ステップ幅の減少率
ITER_MAX = 100 # 外部反復の最大反復数
ind_z = np.cumsum([len(x), len(s), len(lam_s)])[:-1] # 解のインデックス
def compute_kkt(g, gradf, gradg, lam_s, s, rho):
    kkt = np.concatenate([
        gradf+lam_s*gradg, g+s, lam_s*s-rho])
    return kkt # KKT条件の等式をまとめたベクトル
def eval_func(x):
    f = (x[0]-1)**4+(x[0]-2*x[1])**2
    g = x[0]**2-x[1]
    return f, g # 評価関数
def grad(x):
    gradf = np.array([4*(x[0]-1)**3+2*(x[0]-2*x[1]), -4*(x[0]-2*x[1])])
    gradg = np.array([2*x[0], -1])
    return gradf, gradg # 評価関数の勾配
def Hessian(x):
    Hf = np.array([[12*(x[0]-1)**2+2, -4], [-4, 8]])
    Hg = np.array([[2, 0], [0, 0]])
    return Hf, Hg # 評価関数のヘッセ行列
trajectory = [x.copy()] # 設計変数の軌跡
for iter in range(ITER_MAX):
    f, g = eval_func(x)
    gradf, gradg = grad(x)
    tmp_kkt = compute_kkt(g, gradf, gradg, lam_s, s, rho)
    norm_l2_kkt = np.linalg.norm(tmp_kkt, 2) # ユークリッドノルム
    norm_inf_kkt = np.linalg.norm(tmp_kkt, np.inf) # 最大値ノルム
    print(f"{iter} iters, x = ({x[0]:.3f}, {x[1]:.3f}), rho = {rho:.1e}, norm_inf_kkt = {norm_inf_kkt:.1e}")
    if rho < RHO_TOL: break # 外部反復の収束判定
    while norm_inf_kkt > KKT_COEF*rho: # 内部反復
        _, g = eval_func(x)
        gradf, gradg = grad(x)
        Hf, Hg1 = Hessian(x)
        J = np.zeros((4, 4)) # ニュートン法のためのヤコビ行列
        J[np.ix_(np.array([0, 1]),np.array([0, 1]))] += Hf+lam_s*Hg1
        J[np.ix_(np.array([3, 3]),np.array([0, 1]))] += gradg
        J[np.ix_(np.array([0, 1]),np.array([3, 3]))] += gradg[:, None]
        J[3, 2] += 1
        J[2, 3] += s[0]
        J[2, 2] += lam_s[0]
        r_rho = np.zeros(4) # ニュートン法のための右辺ベクトル
        r_rho[[0, 1]] -= gradf+lam_s[0]*gradg
        r_rho[2] -= lam_s[0]*s[0]-rho
        r_rho[3] -= g+s[0]
        dz = np.linalg.solve(J, r_rho) # 連立方程式の求解
        dx, ds, dlam_s = np.split(dz, ind_z) 
        inv_t = np.maximum(-ds/(TAU_TOL*s), -dlam_s/(TAU_TOL*lam_s))
        t = 1/np.maximum(inv_t, 1) # 最大許容ステップ幅
        x_old, s_old, lam_s_old = x.copy(), s.copy(), lam_s.copy()
        tmp_norm_l2_kkt = 2*norm_l2_kkt            
        while tmp_norm_l2_kkt > norm_l2_kkt: # 残差ノルムによる直線探索
            x, s, lam_s = x_old+t*dx, s_old+t*ds, lam_s_old+t*dlam_s
            _, g = eval_func(x)
            gradf, gradg = grad(x)
            tmp_kkt = compute_kkt(g, gradf, gradg, lam_s, s, rho)
            tmp_norm_l2_kkt = np.linalg.norm(tmp_kkt, 2)                
            t = STEP_DECAY*t
        norm_l2_kkt = tmp_norm_l2_kkt
        norm_inf_kkt = np.linalg.norm(tmp_kkt, np.inf)
    rho = RHO_DECAY*rho # バリアパラメータの更新
    trajectory.append(x.copy()) # 設計変数の軌跡を記録
# Out:
# 0 iters, x = (2.000, 1.000), rho = 1.0e+00, norm_inf_kkt = 8.0e+00
# 1 iters, x = (0.601, 0.480), rho = 1.0e-01, norm_inf_kkt = 7.5e-01
# 2 iters, x = (0.503, 0.370), rho = 1.0e-02, norm_inf_kkt = 1.0e-01
# 3 iters, x = (0.567, 0.346), rho = 1.0e-03, norm_inf_kkt = 1.2e-02
# 4 iters, x = (0.586, 0.346), rho = 1.0e-04, norm_inf_kkt = 9.2e-04
# 5 iters, x = (0.588, 0.346), rho = 1.0e-05, norm_inf_kkt = 1.1e-04
# 6 iters, x = (0.588, 0.346), rho = 1.0e-06, norm_inf_kkt = 9.2e-06
# 7 iters, x = (0.588, 0.346), rho = 1.0e-07, norm_inf_kkt = 9.0e-07
# 8 iters, x = (0.588, 0.346), rho = 1.0e-08, norm_inf_kkt = 9.0e-08

# %%
import matplotlib.pyplot as plt
x_p = np.linspace(0, 3, 400)
y_p = np.linspace(0, 3, 400)
X, Y = np.meshgrid(x_p, y_p)
Z, G1 = eval_func(np.array([X, Y]))
feasible_region = (G1 < 0) 
infeasible_region = (G1 > 0) 
contour = plt.contourf(X, Y, Z, levels=40, cmap="viridis", alpha=0.7)
plt.colorbar(label='$f$')
plt.contourf(X, Y, infeasible_region, levels=[0.5, 1], colors='white', alpha=1.0)
constraint1 = plt.contour(X, Y, G1, levels=[0], linestyles='--', colors='black', linewidths=2)
plt.contour(X, Y, Z, levels=40, linestyles='-', linewidths=1, colors='gray', alpha=1)
traj_x = np.squeeze(trajectory)
plt.plot(traj_x[:, 0], traj_x[:, 1], color='k', marker='.', markersize=10, label="Trajectory")
plt.plot(traj_x[0, 0], traj_x[0, 1], color='k', marker='.', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Initial")
plt.plot(traj_x[-1, 0], traj_x[-1, 1],color='k', marker='*', linestyle="", markersize=20, markeredgecolor='w', markeredgewidth=2, label="Optimized")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.gca().set_aspect('equal')
plt.legend(framealpha=1)
